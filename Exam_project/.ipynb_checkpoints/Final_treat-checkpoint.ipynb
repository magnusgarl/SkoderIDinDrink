# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import time

# %% [markdown]
# ### Load The Source From the Webpage

# %%
import csv
import os

directory = 'scrape_raw'
file_list = []

def index_files():
    for filename in os.listdir(directory):
        if os.path.isfile(os.path.join(directory, filename)):
            file_list.append(filename)
    print(file_list)
    return file_list


def import_file(name):
    file_path = os.path.join(directory, name)
    df = pd.read_csv(file_path)
    return df


df
# Out:
#                                            Introduction  Author 1  Author 2  \
# 0     1. IntroductionTheories of imitation, conformi...     Paola   Georgia
# 1     1. IntroductionThe all-or-nothing mechanism is...   Timothy  Robertas
# 2     1. IntroductionA bilateral exchange rate is th...   Michael      None
# 3     1. IntroductionPerformance-contingent bonuses ...      Timo      None
# 4     1. IntroductionSocial media has become an esse...        Ho       Ali
# ...                                                 ...       ...       ...
# 1401  1. IntroductionThe standardNew Keynesian model...   Roberto      None
# 1402  1. IntroductionCommon wisdom is that there has...   Gilbert  Lorraine
# 1403  1. IntroductionTo curb carbon dioxide emission...    Martin   Claudia
# 1404  1. IntroductionDollarization of credits is a v...     Fatih      None
# 1405  1. IntroductionIt has been extensively documen...  Changwei   Chaohua
#
#      Author 3 Author 4 Author 5            Journal  \
# 0        Luis     None     None  Economics Letters
# 1        None     None     None  Economics Letters
# 2        None     None     None  Economics Letters
# 3        None     None     None  Economics Letters
# 4      Sascha    Benno     None  Economics Letters
# ...       ...      ...      ...                ...
# 1401     None     None     None  Economics Letters
# 1402   Thomas     None     None  Economics Letters
# 1403     None     None     None  Economics Letters
# 1404     None     None     None  Economics Letters
# 1405   Lingna     None     None  Economics Letters
#
#                                   Year  Citations Gender_Author 1  \
# 0     Volume 231, October 2023, 111257          0          female
# 1     Volume 231, October 2023, 111265          0            male
# 2     Volume 231, October 2023, 111267          0            male
# 3     Volume 231, October 2023, 111266          0            male
# 4     Volume 231, October 2023, 111270          0         unknown
# ...                                ...        ...             ...
# 1401    Volume 188, March 2020, 108970          5            male
# 1402    Volume 188, March 2020, 108979         15            male
# 1403    Volume 188, March 2020, 108990         10            male
# 1404    Volume 188, March 2020, 108992          1            male
# 1405    Volume 188, March 2020, 109003         14         unknown
#
#      Gender_Author 2 Gender_Author 3 Gender_Author 4 Gender_Author 5  \
# 0             female            male            None            None
# 1               male            None            None            None
# 2               None            None            None            None
# 3               None            None            None            None
# 4               male         unknown            male            None
# ...              ...             ...             ...             ...
# 1401            None            None            None            None
# 1402          female            male            None            None
# 1403          female            None            None            None
# 1404            None            None            None            None
# 1405         unknown         unknown            None            None
#
#      Article_Gender
# 0               Mix
# 1              Male
# 2              Male
# 3              Male
# 4               Mix
# ...             ...
# 1401           Male
# 1402            Mix
# 1403            Mix
# 1404           Male
# 1405            Mix
#
# [1406 rows x 15 columns]

# %% [markdown]
# ## Lav Pandas df

# %% [markdown]
# ### Lav artikel om til df

# %%
def create_df(page_source):
    df_data = []

    for j in range(len(page_source)):
        authors_dict = {}  # Create a new dictionary for each row
        journal_name = []
        citations = []
        year = []
        introduction = []
        possible_id = ['sec_0001','sec_001','sec_01','sec_1','sec1']
        
        soup = bs(page_source[j], 'html.parser')
        
        for ids in possible_id:
            element_with_id = soup.select_one('section#' + ids)
            if element_with_id:
                break 
            
        if element_with_id:
            introduction = element_with_id.get_text(strip=True)
        else:
            introduction = None  # Handle case when element is not found
            print('Intro Error')
        
        # Find all <span> elements with class="given-name"
        author_spans = soup.find_all('span', class_='given-name')

        # Loop through the author spans and populate the dictionary
        for i, author_span in enumerate(author_spans):
            try:
                if i < 5:
                    authors_dict[f'Author {i+1}'] = author_span.get_text().split()[0]
                    if "." in authors_dict[f'Author {i+1}']:
                        author_name = "Unknown"
                        authors_dict[f'Author {i+1}'] = author_name
                else:
                    break
            except AttributeError:
                authors_dict[f'Author {i+1}'] = "None"
                print('error author')
        
        try:
            j_name = soup.find('a', class_="publication-title-link").get_text()
            journal_name = str(j_name)
        except:
            journal_name = "Error no journal name"
            print('error journal')
            
        try:
            cit = soup.find('header', id="citing-articles-header").get_text().split()[2]
            #cit = cit[-1:][:-1]
            #citations = int(cit)
            cit = ''.join(filter(str.isdigit, cit))
            citations = int(cit)
            #citations = cit
        except:
            citations = None
            print('error citations')
            
        try:
            yr = soup.find('div', class_="text-xs").get_text()
            year = yr

        except:
            year = None
            print('error yr')
        
        
        # Append the data for this row to the list of rows
        df_data.append({'Introduction': introduction, **authors_dict, 'Journal': journal_name, 'Year': year, 'Citations': citations})

    df = pd.DataFrame(df_data)

    return df

# %%
### Extract år ###
import re

def extract_year(s):
    year_match = re.search(r'(\d{4})', s)
    if year_match:
        return year_match.group(1)
    else:
        return None

# %% [markdown]
# ## Loop over df og sammensæt df

# %%
def combine_dataframes(list_of_lists):
    combined_df = pd.DataFrame()  # Initialize an empty DataFrame to store the combined data

    for sublist in list_of_lists:
        # Apply create_df function to the sublist and get a dataframe
        df = create_df(sublist)
        
        # Concatenate the current dataframe with the combined dataframe
        combined_df = pd.concat([combined_df, df], ignore_index=True)

    df['Year'] = df['Year'].apply(extract_year)
    df['Author 4'] = df['Author 4'].astype(str)
    df['Author 5'] = df['Author 5'].astype(str)
    
    return combined_df

# %% [markdown]
# ### Behandling af DF

# %%
### Find årstal
### Extract år ###
import re

def extract_year(s):
    year_match = re.search(r'(\d{4})', s)
    if year_match:
        return year_match.group(1)
    else:
        return None
    
df['Year'] = df['Year'].apply(extract_year)
# Out:
#                                         Introduction Author 1  Author 2  \
# 0  1. IntroductionTheories of imitation, conformi...    Paola   Georgia
# 1  1. IntroductionThe all-or-nothing mechanism is...  Timothy  Robertas
# 2  1. IntroductionA bilateral exchange rate is th...  Michael      None
# 3  1. IntroductionPerformance-contingent bonuses ...     Timo      None
# 4  1. IntroductionSocial media has become an esse...       Ho       Ali
# 5  1. IntroductionA series of theoretical models ...  Antoine      None
#
#   Author 3 Author 4 Author 5            Journal  Year  Citations
# 0     Luis     None     None  Economics Letters  2023          0
# 1     None     None     None  Economics Letters  2023          0
# 2     None     None     None  Economics Letters  2023          0
# 3     None     None     None  Economics Letters  2023          0
# 4   Sascha    Benno     None  Economics Letters  2023          0
# 5     None     None     None  Economics Letters  2023          0

# %% [markdown]
# ## Gender

# %%
import gender_guesser.detector as gender

# Initialize the gender detector
detector = gender.Detector()

# Function to predict gender using the genderize.io API
def predict_gender_first_name_api(name):
    api_url = f'https://api.genderize.io?name={name}'
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        try:
            gender = data["gender"].capitalize()
            return gender
        except Exception as e:
            print(f"Error predicting gender for {name}: {e}")
            return "Unknown"
    else:
        #print(f"Request failed. Status code: {response.status_code}")
        return "Unknown"

    

# Function to predict gender for the first name
def predict_gender_first_name(name):
    gender = detector.get_gender(name)
    if name == "None":
        return "None"
    elif "." in name:
        return "None"
        print(name)
    elif gender == "unknown":
        #print("api")
        gender_api = predict_gender_first_name_api(name)
        return gender_api
    else:
        if gender in {'male', 'female'}:
            return gender
        else:
            return "Unknown" 

    
# Apply gender prediction to the first name in each author column and create new gender columns
for i in range(1, 6):
    author_col = f'Author {i}'
    gender_col = f'Gender_{author_col}'
    df[gender_col] = df[author_col].apply(predict_gender_first_name)

# Map the gender predictions to more readable form
#for i in range(1, 6):
#    gender_col = f'Gender_Author {i}'
#    df[gender_col] = df[gender_col].map({
#        'male': 'Male',
#        'female': 'Female',
#        'unknown': 'Unknown',
#    })

# Display the resulting DataFrame
print(df)
# Out:
#                                           Introduction Author 1   Author 2  \
# 0                                                  NaN   August      Paige
# 1                                                  NaN     Paul      Felix
# 2                                                  NaN     Inge   Mauricio
# 3                                                  NaN    Bernd  Françeska
# 4    1. IntroductionPolitical connections are of gr...      Rui    Jiahuan
# ..                                                 ...      ...        ...
# 451                                                NaN     John       Todd
# 452  1. IntroductionOne of the many risks associate...     Eric    Michael
# 453  2. Asymmetric standards and green tariffsThe w...  Alireza       None
# 454  2. The modelThere arempolluters,j= 1, …,m. Pol...    Bouwe       None
# 455                                                NaN    Franz       None
#
#     Author 3 Author 4 Author 5                        Journal  \
# 0     Andrew     None     None  Resource and Energy Economics
# 1     Philip     None     None  Resource and Energy Economics
# 2       None     None     None  Resource and Energy Economics
# 3       None     None     None  Resource and Energy Economics
# 4      Chuan     None     None  Resource and Energy Economics
# ..       ...      ...      ...                            ...
# 451     None     None     None  Resource and Energy Economics
# 452     None     None     None  Resource and Energy Economics
# 453     None     None     None  Resource and Energy Economics
# 454     None     None     None  Resource and Energy Economics
# 455     None     None     None  Resource and Energy Economics
#
#                                                  Year  Citations  \
# 0                      Volume 74, August 2023, 101376          0
# 1                      Volume 74, August 2023, 101386          0
# 2                      Volume 74, August 2023, 101387          0
# 3                      Volume 74, August 2023, 101388          0
# 4                      Volume 74, August 2023, 101390          0
# ..                                                ...        ...
# 451  Volume 29, Issue 4, November 2007, Pages 247-261        138
# 452  Volume 29, Issue 4, November 2007, Pages 262-283         24
# 453  Volume 29, Issue 4, November 2007, Pages 284-299          4
# 454  Volume 29, Issue 4, November 2007, Pages 300-324         11
# 455  Volume 29, Issue 4, November 2007, Pages 325-326          1
#
#     Gender_Author 1 Gender_Author 2 Gender_Author 3 Gender_Author 4  \
# 0              male         Unknown            male            None
# 1              male            male            male            None
# 2            female            male            None            None
# 3              male         Unknown            None            None
# 4              male         Unknown         Unknown            None
# ..              ...             ...             ...             ...
# 451            male            male            None            None
# 452            male            male            None            None
# 453         Unknown            None            None            None
# 454         Unknown            None            None            None
# 455            male            None            None            None
#
#     Gender_Author 5
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ..              ...
# 451            None
# 452            None
# 453            None
# 454            None
# 455            None
#
# [456 rows x 14 columns]

# %%
a = predict_gender_first_name('Ho')
print(a)
# Out:
# Unknown

# %%
for i in range(1, 6):
    gender_col = f'Gender_Author {i}'
    df[gender_col] = df[gender_col].replace('None', None)
    df[gender_col] = df[gender_col].str.lower()

# Function to get the article gender based on author genders
def get_article_gender(row):
    genders = [row[f'Gender_Author {i+1}'] for i in range(5) if not pd.isnull(row[f'Gender_Author {i+1}'])]
    if len(genders) == 0:
        return 'Unknown'
    elif all(gender == 'male' for gender in genders):
        return 'Male'
    elif all(gender == 'female' for gender in genders):
        return 'Female'
    else:
        return 'Mix'

# Apply the function to create the "Article_Gender" column
df['Article_Gender'] = df.apply(get_article_gender, axis=1)

# Display the updated DataFrame
print(df)
female_count = len(df[df['Article_Gender'] == 'Female'])
print(f"Number of rows with 'Article_Gender' == 'Female': {female_count}")
female_count2 = len(df[df['Gender_Author 1'] == 'female'])
print(f"Number of rows with first author == 'Female': {female_count2}")
# Out:
#                                            Introduction  Author 1  Author 2  \
# 0     1. IntroductionTheories of imitation, conformi...     Paola   Georgia
# 1     1. IntroductionThe all-or-nothing mechanism is...   Timothy  Robertas
# 2     1. IntroductionA bilateral exchange rate is th...   Michael      None
# 3     1. IntroductionPerformance-contingent bonuses ...      Timo      None
# 4     1. IntroductionSocial media has become an esse...        Ho       Ali
# ...                                                 ...       ...       ...
# 1401  1. IntroductionThe standardNew Keynesian model...   Roberto      None
# 1402  1. IntroductionCommon wisdom is that there has...   Gilbert  Lorraine
# 1403  1. IntroductionTo curb carbon dioxide emission...    Martin   Claudia
# 1404  1. IntroductionDollarization of credits is a v...     Fatih      None
# 1405  1. IntroductionIt has been extensively documen...  Changwei   Chaohua
#
#      Author 3 Author 4 Author 5            Journal  \
# 0        Luis     None     None  Economics Letters
# 1        None     None     None  Economics Letters
# 2        None     None     None  Economics Letters
# 3        None     None     None  Economics Letters
# 4      Sascha    Benno     None  Economics Letters
# ...       ...      ...      ...                ...
# 1401     None     None     None  Economics Letters
# 1402   Thomas     None     None  Economics Letters
# 1403     None     None     None  Economics Letters
# 1404     None     None     None  Economics Letters
# 1405   Lingna     None     None  Economics Letters
#
#                                   Year  Citations Gender_Author 1  \
# 0     Volume 231, October 2023, 111257          0          female
# 1     Volume 231, October 2023, 111265          0            male
# 2     Volume 231, October 2023, 111267          0            male
# 3     Volume 231, October 2023, 111266          0            male
# 4     Volume 231, October 2023, 111270          0         unknown
# ...                                ...        ...             ...
# 1401    Volume 188, March 2020, 108970          5            male
# 1402    Volume 188, March 2020, 108979         15            male
# 1403    Volume 188, March 2020, 108990         10            male
# 1404    Volume 188, March 2020, 108992          1            male
# 1405    Volume 188, March 2020, 109003         14            male
#
#      Gender_Author 2 Gender_Author 3 Gender_Author 4 Gender_Author 5  \
# 0             female            male            None            None
# 1               male            None            None            None
# 2               None            None            None            None
# 3               None            None            None            None
# 4               male         unknown            male            None
# ...              ...             ...             ...             ...
# 1401            None            None            None            None
# 1402          female            male            None            None
# 1403          female            None            None            None
# 1404            None            None            None            None
# 1405            male          female            None            None
#
#      Article_Gender
# 0               Mix
# 1              Male
# 2              Male
# 3              Male
# 4               Mix
# ...             ...
# 1401           Male
# 1402            Mix
# 1403            Mix
# 1404           Male
# 1405            Mix
#
# [1406 rows x 15 columns]
# Number of rows with 'Article_Gender' == 'Female': 54
# Number of rows with first author == 'Female': 207

# %%
def export_treated(df):
    # Get the name from the first row of the 'Journal' column
    name = df.loc[0, 'Journal']
    
    # Remove any special characters and spaces from the name to make it suitable for a filename
    name = name.replace(' ', '_').replace('.', '').replace(',', '')

    # Define the directory to save the treated data
    treated_directory = 'treated_data'

    # Create the directory if it doesn't exist
    if not os.path.exists(treated_directory):
        os.makedirs(treated_directory)

    # Export the DataFrame to a CSV file within the treated_data directory
    csv_filename = os.path.join(treated_directory, name + '_treated.csv')
    df.to_csv(csv_filename, index=False)

    print(f"DataFrame exported as {csv_filename}")
    
    return 'Success'

# %% [markdown]
# ## Execute: Treat Loop

# %%
files = index_files()
Status = []

for i, j_title in enumerate(files):
    print(j_title)
    df = import_file(j_title)
    
    # Apply gender prediction to the first name in each author column and create new gender columns
    for i in range(1, 6):
        author_col = f'Author {i}'
        gender_col = f'Gender_{author_col}'
        df[gender_col] = df[author_col].apply(predict_gender_first_name)
        
    for i in range(1, 6):
        gender_col = f'Gender_Author {i}'
        df[gender_col] = df[gender_col].replace('None', None)
        df[gender_col] = df[gender_col].str.lower()
        
    # Apply the function to create the "Article_Gender" column
    df['Article_Gender'] = df.apply(get_article_gender, axis=1)

    # Display the updated DataFrame
    df
    female_count = len(df[df['Article_Gender'] == 'Female'])
    print(f"Number of rows with 'Article_Gender' == 'Female': {female_count}")
    female_count2 = len(df[df['Gender_Author 1'] == 'female'])
    print(f"Number of rows with first author == 'Female': {female_count2}")
    
    s = export_treated(df)
    Status.append(s)
# Out:
# ['articles_out_economics-letters.csv', 'articles_out_journal-of-public-economics.csv', 'articles_out_resource-and-energy-economics.csv', 'articles_out_economics-letters.csv', 'articles_out_journal-of-public-economics.csv', 'articles_out_resource-and-energy-economics.csv', 'articles_out_economics-letters.csv', 'articles_out_journal-of-public-economics.csv', 'articles_out_resource-and-energy-economics.csv']
# articles_out_economics-letters.csv
#                                            Introduction  Author 1  Author 2  \
# 0     1. IntroductionTheories of imitation, conformi...     Paola   Georgia
# 1     1. IntroductionThe all-or-nothing mechanism is...   Timothy  Robertas
# 2     1. IntroductionA bilateral exchange rate is th...   Michael      None
# 3     1. IntroductionPerformance-contingent bonuses ...      Timo      None
# 4     1. IntroductionSocial media has become an esse...        Ho       Ali
# ...                                                 ...       ...       ...
# 1401  1. IntroductionThe standardNew Keynesian model...   Roberto      None
# 1402  1. IntroductionCommon wisdom is that there has...   Gilbert  Lorraine
# 1403  1. IntroductionTo curb carbon dioxide emission...    Martin   Claudia
# 1404  1. IntroductionDollarization of credits is a v...     Fatih      None
# 1405  1. IntroductionIt has been extensively documen...  Changwei   Chaohua
#
#      Author 3 Author 4 Author 5            Journal  \
# 0        Luis     None     None  Economics Letters
# 1        None     None     None  Economics Letters
# 2        None     None     None  Economics Letters
# 3        None     None     None  Economics Letters
# 4      Sascha    Benno     None  Economics Letters
# ...       ...      ...      ...                ...
# 1401     None     None     None  Economics Letters
# 1402   Thomas     None     None  Economics Letters
# 1403     None     None     None  Economics Letters
# 1404     None     None     None  Economics Letters
# 1405   Lingna     None     None  Economics Letters
#
#                                   Year  Citations Gender_Author 1  \
# 0     Volume 231, October 2023, 111257          0          female
# 1     Volume 231, October 2023, 111265          0            male
# 2     Volume 231, October 2023, 111267          0            male
# 3     Volume 231, October 2023, 111266          0            male
# 4     Volume 231, October 2023, 111270          0         unknown
# ...                                ...        ...             ...
# 1401    Volume 188, March 2020, 108970          5            male
# 1402    Volume 188, March 2020, 108979         15            male
# 1403    Volume 188, March 2020, 108990         10            male
# 1404    Volume 188, March 2020, 108992          1            male
# 1405    Volume 188, March 2020, 109003         14         unknown
#
#      Gender_Author 2 Gender_Author 3 Gender_Author 4 Gender_Author 5  \
# 0             female            male            None            None
# 1               male            None            None            None
# 2               None            None            None            None
# 3               None            None            None            None
# 4               male         unknown            male            None
# ...              ...             ...             ...             ...
# 1401            None            None            None            None
# 1402          female            male            None            None
# 1403          female            None            None            None
# 1404            None            None            None            None
# 1405         unknown         unknown            None            None
#
#      Article_Gender
# 0               Mix
# 1              Male
# 2              Male
# 3              Male
# 4               Mix
# ...             ...
# 1401           Male
# 1402            Mix
# 1403            Mix
# 1404           Male
# 1405            Mix
#
# [1406 rows x 15 columns]
# Number of rows with 'Article_Gender' == 'Female': 35
# Number of rows with first author == 'Female': 132
# DataFrame exported as treated_data/Economics_Letters_treated.csv
# articles_out_journal-of-public-economics.csv
#                                           Introduction  Author 1 Author 2  \
# 0                                                  NaN    Samuel     None
# 1    1. IntroductionA Potential Pareto Public Good ...   Eduardo    César
# 2                                                  NaN  Adrienne     None
# 3    1. IntroductionFirms respond to increased labo...        Ji  Jungmin
# 4                                                  NaN      None     None
# ..                                                 ...       ...      ...
# 567                                                NaN   Michael   Deepak
# 568                                                NaN       Kai  Stephan
# 569                                                NaN    Jarkko   Tuomas
# 570                                                NaN      Anne  Kristin
# 571                                                NaN    Daniel     None
#
#         Author 3 Author 4 Author 5                      Journal  \
# 0           None     None     None  Journal of Public Economics
# 1           None     None     None  Journal of Public Economics
# 2           None     None     None  Journal of Public Economics
# 3        Kyungho     None     None  Journal of Public Economics
# 4           None     None     None  Journal of Public Economics
# ..           ...      ...      ...                          ...
# 567  Christopher     None     None  Journal of Public Economics
# 568         None     None     None  Journal of Public Economics
# 569         Joel     None     None  Journal of Public Economics
# 570       Jesper     None     None  Journal of Public Economics
# 571         None     None     None  Journal of Public Economics
#
#                                    Year  Citations Gender_Author 1  \
# 0    Volume 225, September 2023, 104947          0            male
# 1    Volume 225, September 2023, 104953          0            male
# 2    Volume 225, September 2023, 104927          0          female
# 3    Volume 225, September 2023, 104951          0         unknown
# 4       Volume 224, August 2023, 104957          0            None
# ..                                  ...        ...             ...
# 567    Volume 181, January 2020, 104083         46            male
# 568    Volume 181, January 2020, 104073         20            male
# 569    Volume 181, January 2020, 104108          4            male
# 570    Volume 181, January 2020, 104115         15          female
# 571    Volume 181, January 2020, 104075          5            male
#
#     Gender_Author 2 Gender_Author 3 Gender_Author 4 Gender_Author 5  \
# 0              None            None            None            None
# 1              male            None            None            None
# 2              None            None            None            None
# 3           unknown         unknown            None            None
# 4              None            None            None            None
# ..              ...             ...             ...             ...
# 567         unknown            male            None            None
# 568            male            None            None            None
# 569            male            male            None            None
# 570          female            male            None            None
# 571            None            None            None            None
#
#     Article_Gender
# 0             Male
# 1             Male
# 2           Female
# 3              Mix
# 4          Unknown
# ..             ...
# 567            Mix
# 568           Male
# 569           Male
# 570            Mix
# 571           Male
#
# [572 rows x 15 columns]
# Number of rows with 'Article_Gender' == 'Female': 29
# Number of rows with first author == 'Female': 103
# DataFrame exported as treated_data/Journal_of_Public_Economics_treated.csv
# articles_out_resource-and-energy-economics.csv
#                                           Introduction Author 1   Author 2  \
# 0                                                  NaN   August      Paige
# 1                                                  NaN     Paul      Felix
# 2                                                  NaN     Inge   Mauricio
# 3                                                  NaN    Bernd  Françeska
# 4    1. IntroductionPolitical connections are of gr...      Rui    Jiahuan
# ..                                                 ...      ...        ...
# 451                                                NaN     John       Todd
# 452  1. IntroductionOne of the many risks associate...     Eric    Michael
# 453  2. Asymmetric standards and green tariffsThe w...  Alireza       None
# 454  2. The modelThere arempolluters,j= 1, …,m. Pol...    Bouwe       None
# 455                                                NaN    Franz       None
#
#     Author 3 Author 4 Author 5                        Journal  \
# 0     Andrew     None     None  Resource and Energy Economics
# 1     Philip     None     None  Resource and Energy Economics
# 2       None     None     None  Resource and Energy Economics
# 3       None     None     None  Resource and Energy Economics
# 4      Chuan     None     None  Resource and Energy Economics
# ..       ...      ...      ...                            ...
# 451     None     None     None  Resource and Energy Economics
# 452     None     None     None  Resource and Energy Economics
# 453     None     None     None  Resource and Energy Economics
# 454     None     None     None  Resource and Energy Economics
# 455     None     None     None  Resource and Energy Economics
#
#                                                  Year  Citations  \
# 0                      Volume 74, August 2023, 101376          0
# 1                      Volume 74, August 2023, 101386          0
# 2                      Volume 74, August 2023, 101387          0
# 3                      Volume 74, August 2023, 101388          0
# 4                      Volume 74, August 2023, 101390          0
# ..                                                ...        ...
# 451  Volume 29, Issue 4, November 2007, Pages 247-261        138
# 452  Volume 29, Issue 4, November 2007, Pages 262-283         24
# 453  Volume 29, Issue 4, November 2007, Pages 284-299          4
# 454  Volume 29, Issue 4, November 2007, Pages 300-324         11
# 455  Volume 29, Issue 4, November 2007, Pages 325-326          1
#
#     Gender_Author 1 Gender_Author 2 Gender_Author 3 Gender_Author 4  \
# 0              male         unknown            male            None
# 1              male            male            male            None
# 2            female            male            None            None
# 3              male         unknown            None            None
# 4              male         unknown         unknown            None
# ..              ...             ...             ...             ...
# 451            male            male            None            None
# 452            male            male            None            None
# 453         unknown            None            None            None
# 454         unknown            None            None            None
# 455            male            None            None            None
#
#     Gender_Author 5 Article_Gender
# 0              None            Mix
# 1              None           Male
# 2              None            Mix
# 3              None            Mix
# 4              None            Mix
# ..              ...            ...
# 451            None           Male
# 452            None           Male
# 453            None            Mix
# 454            None            Mix
# 455            None           Male
#
# [456 rows x 15 columns]
# Number of rows with 'Article_Gender' == 'Female': 18
# Number of rows with first author == 'Female': 64
# DataFrame exported as treated_data/Resource_and_Energy_Economics_treated.csv
# articles_out_economics-letters.csv
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In [66], line 12
#      10     author_col = f'Author {i}'
#      11     gender_col = f'Gender_{author_col}'
# ---> 12     df[gender_col] = df[author_col].apply(predict_gender_first_name)
#      14 for i in range(1, 6):
#      15     gender_col = f'Gender_Author {i}'
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/pandas/core/apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/pandas/core/apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In [65], line 34, in predict_gender_first_name(name)
#      31     print(name)
#      32 elif gender == "unknown":
#      33     #print("api")
# ---> 34     gender_api = predict_gender_first_name_api(name)
#      35     return gender_api
#      36 else:
#
# Cell In [65], line 9, in predict_gender_first_name_api(name)
#       7 def predict_gender_first_name_api(name):
#       8     api_url = f'https://api.genderize.io?name={name}'
# ----> 9     response = requests.get(api_url)
#      10     if response.status_code == 200:
#      11         data = response.json()
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/requests/adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
