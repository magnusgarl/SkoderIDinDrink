# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import gender_guesser.detector as gender

base_url = 'https://link.springer.com/journal/10887/volumes-and-issues/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Create lists to store the scraped data
volumes = []
issues = []
links = []
authors_list = []
titles = []

max_authors = 0  # Variable to store the maximum number of authors across all articles

# Initialize gender detector
detector = gender.Detector()

# Function to get the first name from a full name
def get_first_name(full_name):
    if full_name is not None:
        return full_name.split()[0]
    else:
        return "None"

# Function to predict gender for the first name
def predict_gender_first_name(name):
    if name == "None":
        return "Unknown"
    return detector.get_gender(name)

for volume in range(1, 28):  # Volumes range from 1 to 28
    for issue in range(1, 5):  # Issues range from 1 to 4
        url = base_url + f'{volume}-{issue}'

        response = requests.get(url, headers=headers)

        # If the GET request is successful, the status code will be 200
        if response.status_code == 200:
            # Get the content of the response
            webpage = response.text

            # Create a BeautifulSoup object and specify the parser
            soup = BeautifulSoup(webpage, 'html.parser')

            # Find all parent li tags for each article
            articles = soup.find_all('li', class_='c-list-group__item')

            # For each article, extract the link, author names, and title
            for article in articles:
                # Get the link of the article
                link = article.find('a', href=True)['href']

                # Get the author names
                authors_list_temp = article.select('ul.c-author-list li span')  # Use a temporary variable
                authors = [author.text.strip() for author in authors_list_temp]

                # Get the title
                title = article.find('a', attrs={"data-track": "click"}).text.strip()

                # Append the data to the lists
                volumes.append(volume)
                issues.append(issue)
                links.append(link)
                authors_list.append(authors)  # Store the list of authors directly without joining them
                titles.append(title)

                # Update the maximum number of authors if needed
                max_authors = max(max_authors, len(authors))

                # Sleep for 1 second before the next request
                time.sleep(1)

        else:
            print(f'Request to {url} failed with status code {response.status_code}.')

# Prepare the DataFrame with appropriate columns
columns = ['Volume', 'Issue', 'Link', 'Title'] + [f'Author {i+1}' for i in range(max_authors)]
data = {
    'Volume': volumes,
    'Issue': issues,
    'Link': links,
    'Title': titles
}

for i in range(max_authors):
    data[f'Author {i+1}'] = [authors[i] if len(authors) > i else None for authors in authors_list]

df = pd.DataFrame(data)

# Apply gender prediction to the first name in each author column and create new gender columns
for i in range(max_authors):
    col_name = f'Author {i+1}'
    df[f'Gender_{col_name}'] = df[col_name].apply(get_first_name).apply(predict_gender_first_name)

# Map the gender predictions to more readable form
for i in range(max_authors):
    col_name = f'Gender_Author {i+1}'
    df[col_name] = df[col_name].map({
        'male': 'Male',
        'female': 'Female',
        'unknown': 'Unknown',
        'None': 'Unknown'  # Handle cases where there's no author
    })

# Display the DataFrame
print(df)
# Out:
#      Volume  Issue                                               Link  \
# 0         1      1  https://link.springer.com/article/10.1007/BF00...
# 1         1      1  https://link.springer.com/article/10.1007/BF00...
# 2         1      1  https://link.springer.com/article/10.1007/BF00...
# 3         1      1  https://link.springer.com/article/10.1007/BF00...
# 4         1      1  https://link.springer.com/article/10.1007/BF00...
# ..      ...    ...                                                ...
# 357      27      3  https://link.springer.com/article/10.1007/s108...
# 358      27      3  https://link.springer.com/article/10.1007/s108...
# 359      27      4  https://link.springer.com/article/10.1007/s108...
# 360      27      4  https://link.springer.com/article/10.1007/s108...
# 361      27      4  https://link.springer.com/article/10.1007/s108...
#
#                                                  Title           Author 1  \
# 0                                 Democracy and growth    Robert J. Barro
# 1    Economic development, growth of human capital,...       Jacob Mincer
# 2       Research and development in the growth process    Philippe Aghion
# 3             A theory of persistent income inequality  Steven N. Durlauf
# 4    Convergence empirics across economies with (so...      Danny T. Quah
# ..                                                 ...                ...
# 357  How does scientific progress affect cultural c...  Michela Giorcelli
# 358  State formation, social unrest and cultural di...    Giampaolo Lecce
# 359  Historical social contracts and their legacy: ...        P. Buonanno
# 360  Fascistville: Mussolini’s new towns and the pe...   Mario F. Carillo
# 361  Surname distance and technology diffusion: the...           Ying Bai
#
#                 Author 2         Author 3 Gender_Author 1 Gender_Author 2  \
# 0                   None             None            Male             NaN
# 1                   None             None            Male             NaN
# 2           Peter Howitt             None            Male            Male
# 3                   None             None            Male             NaN
# 4                   None             None            Male             NaN
# ..                   ...              ...             ...             ...
# 357      Nicola Lacetera  Astrid Marinoni          Female          Female
# 358        Laura Ogliari  Tommaso Orlando            Male          Female
# 359        M. Cervellati       G. Prarolo         Unknown         Unknown
# 360                 None             None            Male             NaN
# 361  James Kai-sing Kung             None             NaN            Male
#
#     Gender_Author 3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 357          Female
# 358            Male
# 359         Unknown
# 360             NaN
# 361             NaN
#
# [362 rows x 10 columns]

# %%
import pandas as pd
import gender_guesser.detector as gender

detector = gender.Detector()

def predict_gender_first_name_api(name):
    api_url = 'https://api.genderize.io?name=' + name
    print(api_url)
    response = requests.get(api_url)
    # Check if the request was successful (200 OK)
    if response.status_code == 200:
        data = response.json()  # Parse the response content as JSON
        try:
            gender = data["gender"].capitalize()
            probability = data["probability"]
            if data["gender"] in {'male', 'female'}:
                return data["gender"]
            else:
                return "Unknown"
            
        except Exception as e:
            print(f"Error predicting gender for {name}: {e}")
            return "Unknown"
    else:
        print(f"Request failed. Status code: {response.status_code}")
        return "Unknown"


# Function to get the first name from a full name
def get_first_name(full_name):
    if full_name is not None:
        return full_name.split()[0]
    else:
        return "None"

# Function to predict gender for the first name
def predict_gender_first_name(name):
    gender = detector.get_gender(name)
    if name == "None":
        return "None"
    elif gender == "unknown":
        gender_api = predict_gender_first_name_api(name)
        return gender_api
    else:
        return gender

# Apply gender prediction to the first name in each author column and create new gender columns
df['Gender_Author 1'] = df['Author 1'].apply(get_first_name).apply(predict_gender_first_name)
df['Gender_Author 2'] = df['Author 2'].apply(get_first_name).apply(predict_gender_first_name)
df['Gender_Author 3'] = df['Author 3'].apply(get_first_name).apply(predict_gender_first_name)

#df.drop(columns=['Gender_Author 1', 'Gender_Author 2', 'Gender_Author 3'], inplace=True)

# Map the gender predictions to more readable form
df['Gender_Author 1'] = df['Gender_Author 1'].map({
    'male': 'Male',
    'female': 'Female',
    'unknown': 'Unknown',
})
df['Gender_Author 2'] = df['Gender_Author 2'].map({
    'male': 'Male',
    'female': 'Female',
    'unknown': 'Unknown',
})
df['Gender_Author 3'] = df['Gender_Author 3'].map({
    'male': 'Male',
    'female': 'Female',
    'unknown': 'Unknown',
})

print(df)
# Out:
# https://api.genderize.io?name=Jong-Wha
# Error predicting gender for Jong-Wha: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Chien-Fu
# https://api.genderize.io?name=Momi
# https://api.genderize.io?name=Woojin
# https://api.genderize.io?name=J.
# https://api.genderize.io?name=Lant
# https://api.genderize.io?name=Anandi
# https://api.genderize.io?name=Carl-Johan
# https://api.genderize.io?name=Etsuro
# https://api.genderize.io?name=Abhijit
# https://api.genderize.io?name=Nils-Petter
# https://api.genderize.io?name=Arnab
# https://api.genderize.io?name=Shankha
# https://api.genderize.io?name=Joerg
# https://api.genderize.io?name=L.
# Error predicting gender for L.: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Nils-Petter
# https://api.genderize.io?name=Debasis
# https://api.genderize.io?name=Ragchaasuren
# Error predicting gender for Ragchaasuren: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Hernan
# https://api.genderize.io?name=Mesbah
# https://api.genderize.io?name=C.
# https://api.genderize.io?name=Tuan-Hwee
# Error predicting gender for Tuan-Hwee: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Carl-Johan
# https://api.genderize.io?name=Joerg
# https://api.genderize.io?name=C.
# https://api.genderize.io?name=Ranoua
# Error predicting gender for Ranoua: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Gunes
# https://api.genderize.io?name=Carl-Johan
# https://api.genderize.io?name=Nils-Petter
# https://api.genderize.io?name=Carl-Johan
# https://api.genderize.io?name=Thiago
# https://api.genderize.io?name=Areendam
# Error predicting gender for Areendam: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Hoang-Anh
# Error predicting gender for Hoang-Anh: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=P.
# https://api.genderize.io?name=Sule
# https://api.genderize.io?name=Minseong
# https://api.genderize.io?name=Debraj
# https://api.genderize.io?name=M.
# https://api.genderize.io?name=Areendam
# Error predicting gender for Areendam: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Goncalo
# https://api.genderize.io?name=Gokce
# https://api.genderize.io?name=Mausumi
# https://api.genderize.io?name=Asli
# https://api.genderize.io?name=Lant
# https://api.genderize.io?name=W.
# https://api.genderize.io?name=Hans-Joachim
# https://api.genderize.io?name=Hosny
# https://api.genderize.io?name=Asli
# https://api.genderize.io?name=Jean-François
# https://api.genderize.io?name=Carl-Johan
# https://api.genderize.io?name=M.
# https://api.genderize.io?name=Daishin
# https://api.genderize.io?name=Carl-Johan
# https://api.genderize.io?name=Solomos
# https://api.genderize.io?name=Xueli
# https://api.genderize.io?name=Norikazu
# https://api.genderize.io?name=Muyang
# https://api.genderize.io?name=Alireza
# https://api.genderize.io?name=Martí
# https://api.genderize.io?name=Mounu
# https://api.genderize.io?name=Md.
# https://api.genderize.io?name=L.
# Error predicting gender for L.: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Iftekhar
# https://api.genderize.io?name=Bulent
# https://api.genderize.io?name=Èric
# https://api.genderize.io?name=M.
# https://api.genderize.io?name=Mancur
# https://api.genderize.io?name=Mancur
# https://api.genderize.io?name=Jaypee
# https://api.genderize.io?name=Rajabrata
# Error predicting gender for Rajabrata: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Yorbol
# Error predicting gender for Yorbol: 'NoneType' object has no attribute 'capitalize'
# https://api.genderize.io?name=Hosny
# https://api.genderize.io?name=Pierre-Louis
# https://api.genderize.io?name=Xueli
# https://api.genderize.io?name=G.
#      Volume  Issue                                               Link  \
# 0         1      1  https://link.springer.com/article/10.1007/BF00...
# 1         1      1  https://link.springer.com/article/10.1007/BF00...
# 2         1      1  https://link.springer.com/article/10.1007/BF00...
# 3         1      1  https://link.springer.com/article/10.1007/BF00...
# 4         1      1  https://link.springer.com/article/10.1007/BF00...
# ..      ...    ...                                                ...
# 357      27      3  https://link.springer.com/article/10.1007/s108...
# 358      27      3  https://link.springer.com/article/10.1007/s108...
# 359      27      4  https://link.springer.com/article/10.1007/s108...
# 360      27      4  https://link.springer.com/article/10.1007/s108...
# 361      27      4  https://link.springer.com/article/10.1007/s108...
#
#                                                  Title           Author 1  \
# 0                                 Democracy and growth    Robert J. Barro
# 1    Economic development, growth of human capital,...       Jacob Mincer
# 2       Research and development in the growth process    Philippe Aghion
# 3             A theory of persistent income inequality  Steven N. Durlauf
# 4    Convergence empirics across economies with (so...      Danny T. Quah
# ..                                                 ...                ...
# 357  How does scientific progress affect cultural c...  Michela Giorcelli
# 358  State formation, social unrest and cultural di...    Giampaolo Lecce
# 359  Historical social contracts and their legacy: ...        P. Buonanno
# 360  Fascistville: Mussolini’s new towns and the pe...   Mario F. Carillo
# 361  Surname distance and technology diffusion: the...           Ying Bai
#
#                 Author 2         Author 3 Gender_Author 1 Gender_Author 2  \
# 0                   None             None            Male             NaN
# 1                   None             None            Male             NaN
# 2           Peter Howitt             None            Male            Male
# 3                   None             None            Male             NaN
# 4                   None             None            Male             NaN
# ..                   ...              ...             ...             ...
# 357      Nicola Lacetera  Astrid Marinoni          Female          Female
# 358        Laura Ogliari  Tommaso Orlando            Male          Female
# 359        M. Cervellati       G. Prarolo            Male            Male
# 360                 None             None            Male             NaN
# 361  James Kai-sing Kung             None             NaN            Male
#
#     Gender_Author 3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 357          Female
# 358            Male
# 359            Male
# 360             NaN
# 361             NaN
#
# [362 rows x 10 columns]

# %%
# Function to get the article gender based on author genders
def get_article_gender(row):
    genders = [row[f'Gender_Author {i+1}'] for i in range(3) if not pd.isnull(row[f'Gender_Author {i+1}'])]
    if len(genders) == 0:
        return 'Unknown'
    elif all(gender == 'Male' for gender in genders):
        return 'Male'
    elif all(gender == 'Female' for gender in genders):
        return 'Female'
    else:
        return 'Mix'

# Apply the function to create the "Article_Gender" column
df['Article_Gender'] = df.apply(get_article_gender, axis=1)

# Display the updated DataFrame
print(df)
# Out:
#      Volume  Issue                                               Link  \
# 0         1      1  https://link.springer.com/article/10.1007/BF00...
# 1         1      1  https://link.springer.com/article/10.1007/BF00...
# 2         1      1  https://link.springer.com/article/10.1007/BF00...
# 3         1      1  https://link.springer.com/article/10.1007/BF00...
# 4         1      1  https://link.springer.com/article/10.1007/BF00...
# ..      ...    ...                                                ...
# 357      27      3  https://link.springer.com/article/10.1007/s108...
# 358      27      3  https://link.springer.com/article/10.1007/s108...
# 359      27      4  https://link.springer.com/article/10.1007/s108...
# 360      27      4  https://link.springer.com/article/10.1007/s108...
# 361      27      4  https://link.springer.com/article/10.1007/s108...
#
#                                                  Title           Author 1  \
# 0                                 Democracy and growth    Robert J. Barro
# 1    Economic development, growth of human capital,...       Jacob Mincer
# 2       Research and development in the growth process    Philippe Aghion
# 3             A theory of persistent income inequality  Steven N. Durlauf
# 4    Convergence empirics across economies with (so...      Danny T. Quah
# ..                                                 ...                ...
# 357  How does scientific progress affect cultural c...  Michela Giorcelli
# 358  State formation, social unrest and cultural di...    Giampaolo Lecce
# 359  Historical social contracts and their legacy: ...        P. Buonanno
# 360  Fascistville: Mussolini’s new towns and the pe...   Mario F. Carillo
# 361  Surname distance and technology diffusion: the...           Ying Bai
#
#                 Author 2         Author 3 Gender_Author 1 Gender_Author 2  \
# 0                   None             None            Male             NaN
# 1                   None             None            Male             NaN
# 2           Peter Howitt             None            Male            Male
# 3                   None             None            Male             NaN
# 4                   None             None            Male             NaN
# ..                   ...              ...             ...             ...
# 357      Nicola Lacetera  Astrid Marinoni          Female          Female
# 358        Laura Ogliari  Tommaso Orlando            Male          Female
# 359        M. Cervellati       G. Prarolo            Male            Male
# 360                 None             None            Male             NaN
# 361  James Kai-sing Kung             None             NaN            Male
#
#     Gender_Author 3 Article_Gender
# 0               NaN           Male
# 1               NaN           Male
# 2               NaN           Male
# 3               NaN           Male
# 4               NaN           Male
# ..              ...            ...
# 357          Female         Female
# 358            Male            Mix
# 359            Male           Male
# 360             NaN           Male
# 361             NaN           Male
#
# [362 rows x 11 columns]

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

def scrape_intro_requests(url):
    response = requests.get(url)
    if response.status_code == 200:
        webpage = response.text
        soup = BeautifulSoup(webpage, 'html.parser')
        intro_div = soup.find('div', class_='c-article-section__content', id='Sec1-content')
        if intro_div:
            paragraphs = intro_div.find_all('p')
            return ' '.join(p.get_text() for p in paragraphs)
    return None

# Iterate through the DataFrame and scrape the content for "Male" and "Female" observations
for index, row in df.iterrows():
    if row['Article_Gender'] in ['Male', 'Female']:
        intro = scrape_intro_requests(row['Link'])
        df.at[index, 'Intro'] = intro

# Display the updated DataFrame
print(df)
# Out:
#      Volume  Issue                                               Link  \
# 0         1      1  https://link.springer.com/article/10.1007/BF00...
# 1         1      1  https://link.springer.com/article/10.1007/BF00...
# 2         1      1  https://link.springer.com/article/10.1007/BF00...
# 3         1      1  https://link.springer.com/article/10.1007/BF00...
# 4         1      1  https://link.springer.com/article/10.1007/BF00...
# ..      ...    ...                                                ...
# 357      27      3  https://link.springer.com/article/10.1007/s108...
# 358      27      3  https://link.springer.com/article/10.1007/s108...
# 359      27      4  https://link.springer.com/article/10.1007/s108...
# 360      27      4  https://link.springer.com/article/10.1007/s108...
# 361      27      4  https://link.springer.com/article/10.1007/s108...
#
#                                                  Title           Author 1  \
# 0                                 Democracy and growth    Robert J. Barro
# 1    Economic development, growth of human capital,...       Jacob Mincer
# 2       Research and development in the growth process    Philippe Aghion
# 3             A theory of persistent income inequality  Steven N. Durlauf
# 4    Convergence empirics across economies with (so...      Danny T. Quah
# ..                                                 ...                ...
# 357  How does scientific progress affect cultural c...  Michela Giorcelli
# 358  State formation, social unrest and cultural di...    Giampaolo Lecce
# 359  Historical social contracts and their legacy: ...        P. Buonanno
# 360  Fascistville: Mussolini’s new towns and the pe...   Mario F. Carillo
# 361  Surname distance and technology diffusion: the...           Ying Bai
#
#                 Author 2         Author 3 Gender_Author 1 Gender_Author 2  \
# 0                   None             None            Male             NaN
# 1                   None             None            Male             NaN
# 2           Peter Howitt             None            Male            Male
# 3                   None             None            Male             NaN
# 4                   None             None            Male             NaN
# ..                   ...              ...             ...             ...
# 357      Nicola Lacetera  Astrid Marinoni          Female          Female
# 358        Laura Ogliari  Tommaso Orlando            Male          Female
# 359        M. Cervellati       G. Prarolo            Male            Male
# 360                 None             None            Male             NaN
# 361  James Kai-sing Kung             None             NaN            Male
#
#     Gender_Author 3 Article_Gender  \
# 0               NaN           Male
# 1               NaN           Male
# 2               NaN           Male
# 3               NaN           Male
# 4               NaN           Male
# ..              ...            ...
# 357          Female         Female
# 358            Male            Mix
# 359            Male           Male
# 360             NaN           Male
# 361             NaN           Male
#
#                                                  Intro
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 357  “Economic change in all periods depends, more ...
# 358                                                NaN
# 359  The medieval republics, the self-governed city...
# 360  Nationalism, racial resentment, xenophobia, an...
# 361  Since Adam Smith’s time, the question of why i...
#
# [362 rows x 12 columns]

# %%
# Iterate through the DataFrame and set "Intro_check" based on the presence of "Intro"
df['Intro_check'] = df['Intro'].notnull().astype(int)

# Display the updated DataFrame
print(df)
# Out:
#      Volume  Issue                                               Link  \
# 0         1      1  https://link.springer.com/article/10.1007/BF00...
# 1         1      1  https://link.springer.com/article/10.1007/BF00...
# 2         1      1  https://link.springer.com/article/10.1007/BF00...
# 3         1      1  https://link.springer.com/article/10.1007/BF00...
# 4         1      1  https://link.springer.com/article/10.1007/BF00...
# ..      ...    ...                                                ...
# 357      27      3  https://link.springer.com/article/10.1007/s108...
# 358      27      3  https://link.springer.com/article/10.1007/s108...
# 359      27      4  https://link.springer.com/article/10.1007/s108...
# 360      27      4  https://link.springer.com/article/10.1007/s108...
# 361      27      4  https://link.springer.com/article/10.1007/s108...
#
#                                                  Title           Author 1  \
# 0                                 Democracy and growth    Robert J. Barro
# 1    Economic development, growth of human capital,...       Jacob Mincer
# 2       Research and development in the growth process    Philippe Aghion
# 3             A theory of persistent income inequality  Steven N. Durlauf
# 4    Convergence empirics across economies with (so...      Danny T. Quah
# ..                                                 ...                ...
# 357  How does scientific progress affect cultural c...  Michela Giorcelli
# 358  State formation, social unrest and cultural di...    Giampaolo Lecce
# 359  Historical social contracts and their legacy: ...        P. Buonanno
# 360  Fascistville: Mussolini’s new towns and the pe...   Mario F. Carillo
# 361  Surname distance and technology diffusion: the...           Ying Bai
#
#                 Author 2         Author 3 Gender_Author 1 Gender_Author 2  \
# 0                   None             None            Male             NaN
# 1                   None             None            Male             NaN
# 2           Peter Howitt             None            Male            Male
# 3                   None             None            Male             NaN
# 4                   None             None            Male             NaN
# ..                   ...              ...             ...             ...
# 357      Nicola Lacetera  Astrid Marinoni          Female          Female
# 358        Laura Ogliari  Tommaso Orlando            Male          Female
# 359        M. Cervellati       G. Prarolo            Male            Male
# 360                 None             None            Male             NaN
# 361  James Kai-sing Kung             None             NaN            Male
#
#     Gender_Author 3 Article_Gender  \
# 0               NaN           Male
# 1               NaN           Male
# 2               NaN           Male
# 3               NaN           Male
# 4               NaN           Male
# ..              ...            ...
# 357          Female         Female
# 358            Male            Mix
# 359            Male           Male
# 360             NaN           Male
# 361             NaN           Male
#
#                                                  Intro  Intro_check
# 0                                                  NaN            0
# 1                                                  NaN            0
# 2                                                  NaN            0
# 3                                                  NaN            0
# 4                                                  NaN            0
# ..                                                 ...          ...
# 357  “Economic change in all periods depends, more ...            1
# 358                                                NaN            0
# 359  The medieval republics, the self-governed city...            1
# 360  Nationalism, racial resentment, xenophobia, an...            1
# 361  Since Adam Smith’s time, the question of why i...            1
#
# [362 rows x 13 columns]

# %%
import os
import pandas as pd

# Assuming 'df' is your DataFrame
# For example:
# df = pd.DataFrame({'Column1': [1, 2, 3], 'Column2': ['A', 'B', 'C']})

# Get the current working directory
current_directory = os.getcwd()

# Define the file name you want to save
file_name = 'Springer_dataframe.csv'

# Join the current directory with the file name
file_path = os.path.join(current_directory, file_name)

# Save the DataFrame to CSV
df.to_csv(file_path, index=False)

print(f"DataFrame has been saved to '{file_path}'.")
# Out:
# DataFrame has been saved to '/Users/Magnus/Documents/GitHub/SkoderIDinDrink/Exam_project/Springer_dataframe.csv'.
